# %%
import numpy as np
from matplotlib import pyplot as plt
import Noise_Interferometry
import ooipy
import pickle

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
filename = '/Volumes/Ocean_Acoustics/NCCFs/MJ03F-MJ03E/Longterm_MA_2017_201.pkl'
nccfs = pickle.load( open( filename, "rb" ) )

# %%
peak_names = ['dA', 's1b0A', 's2b1A', 'dB', 's1b0B', 's2b1B']

k = 1
for peak_name in peak_names:
    plt.subplot(2,3,k)
    plt.imshow(nccfs.peaks[peak_name], aspect='auto',cmap='jet',origin='lower')
    
    k += 1
    
plt.tight_layout()

# %%
nccfs.SNR_debug()
