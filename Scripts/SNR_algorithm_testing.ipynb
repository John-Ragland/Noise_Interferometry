# %%
import numpy as np
from matplotlib import pyplot as plt
import Noise_Interferometry
import ooipy
import pickle

# Some more magic so that the notebook will reload external python modules;
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
filename = '/Volumes/Ocean_Acoustics/NCCFs/MJ03F-MJ03E/Longterm_MA_2017_201.pkl'
nccfs = pickle.load( open( filename, "rb" ) )

# %%
nccfs.SNR_debug('s2b1A')

# %%
plt.plot(np.sum(np.abs(nccfs.NCCFs_c[:,nccfs.peak_slices['dA']]),axis=0))
